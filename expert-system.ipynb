# %% [markdown]
# # Assign 1
#
# Copy and paste Python code with your expert system implementation in the cell below and run it:

# %%
# YOUR (2C) CODE HERE! You can delete everything in this cell and write your own code.
from experta import *

# %% [markdown]
# **2c.** Copy and paste Python code with an example input into the cell below:

# %%
# YOUR (2D) CODE HERE! You can delete everything in this cell and write your own code.

# %% [markdown]
# **2d.** Copy and paste Python code with another example input into the cell below:

# %%
# YOUR (2D) CODE HERE! You can delete everything in this cell and write your own code.
